# %%
d!wget https://huggingface.co/datasets/Jgmorenof/teaching_tools_2025/resolve/main/chef-douvre.zip
# Out:
# --2026-02-02 15:29:38--  https://huggingface.co/datasets/Jgmorenof/teaching_tools_2025/resolve/main/chef-douvre.zip
# Resolving huggingface.co (huggingface.co)... 3.168.73.111, 3.168.73.38, 3.168.73.106, ...
# Connecting to huggingface.co (huggingface.co)|3.168.73.111|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us/68a6cbb4eefddf148411cee1/54a51d564f259297a0705d4873bb2975d6589c79119ea8729eb93788a856ab4d?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27chef-douvre.zip%3B+filename%3D%22chef-douvre.zip%22%3B&response-content-type=application%2Fzip&Expires=1770049779&Policy=&Signature=upj7wtJ-UZQSRV-8dejuY-oSPhwlU0Ho6ijh-0zyQENjnhNVcZDsUMXzjAuM5r6FPkgsv7RcEP2xfAnE7lePfJ-cG1nrhD21kjC8G56p23xTtBoBSTzruALVQFK%7Ey20dNBOhD0WnmlXfR-NLl8T9LHEPvoe7agEmL9X8t1TGnlUmHNTAMGBo8MZtWF%7E5g7d-cGqyktVVJFaEn6TB1tvyK1ZRfh6s%7EVuD7SY0-djF8EPvSC0bz3kZR1MIFTCIfLgKjE5b2QBmiBO6juBEIh8SwUJa9jkfdzT8Ox4L8Yg8loJAHbJnLHeuWTvHgqVoQMHl73xlDgdQiPO403MQHzbFbg__&Key-Pair-Id=KJLH8B0YWU4Y8M [following]
# --2026-02-02 15:29:39--  https://us.gcp.cdn.hf.co/xet-bridge-us/68a6cbb4eefddf148411cee1/54a51d564f259297a0705d4873bb2975d6589c79119ea8729eb93788a856ab4d?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27chef-douvre.zip%3B+filename%3D%22chef-douvre.zip%22%3B&response-content-type=application%2Fzip&Expires=1770049779&Policy=&Signature=upj7wtJ-UZQSRV-8dejuY-oSPhwlU0Ho6ijh-0zyQENjnhNVcZDsUMXzjAuM5r6FPkgsv7RcEP2xfAnE7lePfJ-cG1nrhD21kjC8G56p23xTtBoBSTzruALVQFK%7Ey20dNBOhD0WnmlXfR-NLl8T9LHEPvoe7agEmL9X8t1TGnlUmHNTAMGBo8MZtWF%7E5g7d-cGqyktVVJFaEn6TB1tvyK1ZRfh6s%7EVuD7SY0-djF8EPvSC0bz3kZR1MIFTCIfLgKjE5b2QBmiBO6juBEIh8SwUJa9jkfdzT8Ox4L8Yg8loJAHbJnLHeuWTvHgqVoQMHl73xlDgdQiPO403MQHzbFbg__&Key-Pair-Id=KJLH8B0YWU4Y8M
# Resolving us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)... 34.120.165.110
# Connecting to us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)|34.120.165.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3249161606 (3.0G) [application/zip]
# Saving to: ‘chef-douvre.zip’
#
# chef-douvre.zip     100%[===================>]   3.03G  55.3MB/s    in 48s
#
# 2026-02-02 15:30:27 (64.7 MB/s) - ‘chef-douvre.zip’ saved [3249161606/3249161606]

# %%
# # List the files in the zip, take the first 100, and unzip them
# !unzip -l chef-douvre.zip '/content/drive/MyDrive/chef-douvre/AS_TrainingSet_BnF_NewsEye_v3/*' -d /content/
# !unzip chef-douvre.zip 'chef-douvre/AS_TrainingSet_BnF_NewsEye_v2/*' -d /content/
# Out:
# caution:  not extracting; -d ignored
# Archive:  chef-douvre.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
# ---------                     -------
#         0                     0 files

# %%
from pathlib import Path

# Chemins de vos dossiers
data1 = Path("/content/drive/MyDrive/chef-douvre/AS_TrainingSet_BnF_NewsEye_v2")
data2 = Path("/content/drive/MyDrive/chef-douvre/data")

# On compte tous les fichiers (*) dans les deux dossiers
fichiers_data1 = list(data1.glob("*"))
fichiers_data2 = list(data2.glob("*"))

print(f"Fichiers dans data1 : {len(fichiers_data1)}")
print(f"Fichiers dans data2 : {len(fichiers_data2)}")
print(f"Total : {len(fichiers_data1) + len(fichiers_data2)}")
# Out:
# Fichiers dans data1 : 97
# Fichiers dans data2 : 120
# Total : 217

# %%
# !unzip -j chef-douvre.zip "chef-douvre/AS_TrainingSet_BnF_NewsEye_v2/*.xml" -d /content/drive/MyDrive/chef-douvre/data
# Out:
# Archive:  chef-douvre.zip
#   inflating: /content/drive/MyDrive/chef-douvre/data/19140115_1-0005.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18840315_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19180115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18740715_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19260115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18980115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18940115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18700715_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19140115_1-0007.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18690715_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18730715_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18680715_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19300115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19120115_1-0007.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19280115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19120115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18880115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18690715_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18980715_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19220115_1-0005.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18690715_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19040115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19020115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18920115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18840315_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19150115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19160115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18730715_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18730715_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18970715_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19000715_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19140115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19140115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19190115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18980115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19060115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19260115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18710715_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19200115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19140115_1-0008.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19220115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18720715_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18750715_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19040115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18680715_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19200115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19120115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19300115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19080115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19100115_1-0005.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19260115_1-0006.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18740715_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18990715_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19150115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19280115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19000715_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18730715_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18750715_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19020115_1-0005.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18690715_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19260115_1-0007.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19100115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19000115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19120115_1-0006.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18980715_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19300115_1-0007.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19020115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18860115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18960115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19150115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18710715_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19080115_1-0005.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19280115_1-0006.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19100115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19040115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18960115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18720715_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19100115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19000115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18980715_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19300115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18990715_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19150115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18940115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18750715_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18840315_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18900115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19300115_1-0005.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19080115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18740715_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18980115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18880115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18900115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19020115_1-0006.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19300115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19060115_1-0005.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19280115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18860115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19220115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18960115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19140115_1-0006.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18880115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18700715_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19140115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19080115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19260115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18970715_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18990715_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18710715_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19020115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18750715_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19240115_1-0005.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18720715_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19300115_1-0008.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19120115_1-0008.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19120115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19240115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19080115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18900115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19260115_1-0008.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18680715_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18940115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18980115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18700715_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18960115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18860115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19200115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19080115_1-0006.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19180115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19240115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18900115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19160115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18840315_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19060115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19160115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19260115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18740715_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18860115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18940115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19000715_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19220115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18680715_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19040115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18990715_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19120115_1-0005.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19180115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19020115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19240115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19180115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19000115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19280115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19300115_1-0006.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19060115_1-0006.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18710715_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18700715_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19220115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18920115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18720715_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19100115_1-0006.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19000115_1-0005.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19040115_1-0005.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18970715_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18920115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18980715_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18920115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19000115_1-0006.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19060115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19140115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19240115_1-0006.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19000115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19220115_1-0006.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19060115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19200115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19000715_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19160115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19260115_1-0005.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19100115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19190115_1-0002.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19120115_1-0001.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19240115_1-0003.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19280115_1-0005.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/18880115_1-0004.xml
#   inflating: /content/drive/MyDrive/chef-douvre/data/19040115_1-0006.xml

# %%
# !pip install sentence-transformers lxml scikit-learn
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (6.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.57.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.9.0+cpu)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 377, in run
#     requirement_set = resolver.resolve(
#                       ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/resolution/resolvelib/resolver.py", line 95, in resolve
#     result = self._result = resolver.resolve(
#                             ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 229, in _get_updated_criteria
#     for requirement in self._p.get_dependencies(candidate=candidate):
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/resolution/resolvelib/provider.py", line 247, in get_dependencies
#     return [r for r in candidate.iter_dependencies(with_requires) if r is not None]
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/resolution/resolvelib/candidates.py", line 401, in iter_dependencies
#     for r in self.dist.iter_dependencies():
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/importlib/_dists.py", line 222, in iter_dependencies
#     req = Requirement(req_string.strip())
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/requirements.py", line 36, in __init__
#     parsed = _parse_requirement(requirement_string)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_parser.py", line 62, in parse_requirement
#     return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_parser.py", line 71, in _parse_requirement
#     name_token = tokenizer.expect(
#                  ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_tokenizer.py", line 141, in expect
#     if not self.check(name):
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_tokenizer.py", line 133, in check
#     self.next_token = Token(name, match[0], self.position)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 2, in __init__
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 216, in exc_logging_wrapper
#     logger.debug("Exception information:", exc_info=True)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1527, in debug
#     self._log(DEBUG, msg, args, **kwargs)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1684, in _log
#     self.handle(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1028, in handle
#     self.emit(record)
#   File "/usr/lib/python3.12/logging/handlers.py", line 75, in emit
#     logging.FileHandler.emit(self, record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1280, in emit
#     StreamHandler.emit(self, record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/utils/logging.py", line 112, in format
#     formatted = super().format(record)
#                 ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 711, in format
#     record.exc_text = self.formatException(record.exc_info)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 661, in formatException
#     traceback.print_exception(ei[0], ei[1], tb, None, sio)
#   File "/usr/lib/python3.12/traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 733, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 438, in _extract_from_extended_frame_gen
#     f.line
#   File "/usr/lib/python3.12/traceback.py", line 323, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/linecache.py", line 141, in updatecache
#     with tokenize.open(fullname) as fp:
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/tokenize.py", line 457, in open
#     buffer = _builtin_open(filename, 'rb')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %%
from sklearn.metrics.pairwise import cosine_distances, euclidean_distances
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import adjusted_rand_score, v_measure_score

# %%
import numpy as np
import pandas as pd
from lxml import etree
from pathlib import Path
from tqdm.auto import tqdm
import re
import unicodedata

def parse_xml_custom(xml_path):
    # Espace de noms standard pour les fichiers PAGE XML
    NS = {"ns": "http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15"}
    try:
        tree = etree.parse(str(xml_path))
    except: return []

    root = tree.getroot()
    page = root.find(".//ns:Page", namespaces=NS)
    w = float(page.get("imageWidth") or 1)
    h = float(page.get("imageHeight") or 1)

    file_name = Path(xml_path).name

    blocks = []
    # On itère sur les TextRegion
    for region in root.findall(".//ns:TextRegion", namespaces=NS):

        # 1. Extraire l'ID du bloc (ex: r_3_211)
        block_id = region.get("id")

        ground_truth_id = "N/A"
        first_line = region.find(".//ns:TextLine", namespaces=NS)
        if first_line is not None:
            custom = first_line.get("custom") or ""
            if "structure {id:" in custom:
                extracted_id = custom.split("structure {id:")[1].split("}")[0].split(";")[0].strip()
                # ON CRÉE L'ID UNIQUE ICI
                ground_truth_id = f"{file_name}_{extracted_id}"

        # 3. Extraire le texte (dernier Unicode disponible pour la région)
        text_nodes = region.findall(".//ns:TextEquiv/ns:Unicode", namespaces=NS)
        raw_text = text_nodes[-1].text.strip() if text_nodes and text_nodes[-1].text else ""
        if not raw_text: continue

        #         1. Ce qu'il y a dans le XML (Le Polygone)

        # Les coordonnées <Coords points="3453,1038 3613,1038 3613,1080 3453,1080"/> représentent les quatre coins du rectangle (ou de la zone) qui entoure ton texte.

        #     Chaque paire est un point (x,y) sur l'image originale.

        # 2. Ce que fait ton code (Le Centroïde)

        # La partie de ton code avec min(xs), max(xs), min(ys) et max(ys) calcule le centre géométrique (le "centroïde") de ce rectangle.

        #     cx : C'est la position horizontale moyenne (le milieu entre la gauche et la droite).

        #     cy : C'est la position verticale moyenne (le milieu entre le haut et le bas).

        # 4. Extraire les coordonnées (points)
        coords_node = region.find(".//ns:Coords", namespaces=NS)
        pts_str = coords_node.get("points") if coords_node is not None else ""

        # Calcul du centre relatif pour les coordonnées simplifiées (cx, cy)
        try:
            pts = [tuple(map(float, p.split(","))) for p in pts_str.split() if "," in p]
            xs, ys = zip(*pts)
            cx, cy = (min(xs) + max(xs)) / 2 / w, (min(ys) + max(ys)) / 2 / h
            coords_tuple = (cx, cy)
        except:
            coords_tuple = (0.5, 0.5)

        blocks.append({
            "block_id": block_id,
            "coords": coords_tuple,
            "text": raw_text,
            "article_id": ground_truth_id, # Maintenant unique : ex: "19220115_1-0005.xml_a12"
            "embedding": None,
            "source_file": file_name
        })
    return blocks

def nettoyer_ocr_avance(texte):
    if not isinstance(texte, str): return ""
    texte = unicodedata.normalize('NFKC', texte)
    texte = texte.lower()
    texte = re.sub(r'[¬\-]\s*', '', texte) # Gestion des césures
    texte = re.sub(r"[|/\\]", " ", texte)
    texte = re.sub(r"\s'|'\s", "'", texte)
    texte = re.sub(r'[^a-z0-9àâçéèêëîïôûù\s\',.]', ' ', texte)
    texte = re.sub(r'\s+', ' ', texte).strip()
    return texte

# --- EXÉCUTION ---
folder_path = "/content/drive/MyDrive/chef-douvre/AS_TrainingSet_BnF_NewsEye_v2"
data = []

# --- START OF MODIFICATION ---
# Check if the target directory exists and contains XML files
target_folder_path_obj = Path(folder_path)
zip_file_path_obj = Path("/content/chef-douvre.zip")

if not target_folder_path_obj.exists() or not any(target_folder_path_obj.glob("*.xml")):
    print(f"Directory {folder_path} is empty or does not exist.")
    if zip_file_path_obj.exists():
        print("Attempting to unzip 'chef-douvre.zip' to '/content/drive/MyDrive/'.")
        # Ensure the base directory for extraction exists
        Path("/content/drive/MyDrive/").mkdir(parents=True, exist_ok=True)
        # Use !unzip for simplicity in Colab, assuming it's available.
        # This command extracts the 'chef-douvre' folder from the zip into /content/drive/MyDrive/
        get_ipython().system(f"unzip -q {zip_file_path_obj} -d /content/drive/MyDrive/")
        print("Unzipping complete. Re-checking for XML files.")
    else:
        print(f"Warning: '{zip_file_path_obj}' not found. Cannot proceed without the zip file.")
        print("Please ensure 'chef-douvre.zip' is downloaded to /content/ and Google Drive is mounted.")

files = list(target_folder_path_obj.glob("*.xml")) # Use the Path object

if not files:
    print(f"No XML files found in {folder_path} after unzipping attempt. The DataFrame will be empty.")
    # Create an empty DataFrame with expected columns to prevent KeyError
    df = pd.DataFrame(columns=['block_id', 'coords', 'text', 'article_id', 'embedding', 'source_file'])
else:
    for f in tqdm(files, desc="Traitement des fichiers"):
        data.extend(parse_xml_custom(f))
    df = pd.DataFrame(data)

# --- END OF MODIFICATION ---

# Nettoyage final du texte
# Apply cleaning only if 'text' column exists and df is not empty
if 'text' in df.columns and not df.empty:
    df['text'] = df['text'].apply(nettoyer_ocr_avance)
else:
    print("Skipping text cleaning as 'text' column is missing or DataFrame is empty.")

# On réorganise les colonnes comme demandé
expected_cols = ['block_id', 'coords', 'text', 'article_id', 'embedding', 'source_file']
# Filter for columns that actually exist in the DataFrame
df_cols_to_keep = [col for col in expected_cols if col in df.columns]
df = df[df_cols_to_keep] # Reassign df with existing and desired columns

# Affichage stylisé pour VS Code ou Colab
from IPython.display import display

if not df.empty:
    # On définit un style pour que le texte long ne casse pas l'affichage
    styled_df = df.head(15).style.set_properties(**{
        'text-align': 'left',
        'border-color': 'white',
        'font-size': '12px'
    }).set_table_styles([
        {'selector': 'th', 'props': [('background-color', '#4CAF50'), ('color', 'white')]}
    ])

    display(styled_df)
else:
    print("DataFrame is empty, no styled DataFrame to display.")


# Petit bonus : Compter combien vous avez de chaque type d'ID
if 'block_id' in df.columns and not df.empty:
    id_type = df['block_id'].apply(lambda x: 'Manuel (Region_...)' if 'region' in x.lower() else 'Auto (r_...)')
    print("\nStatistiques des types de blocs :")
    print(id_type.value_counts())
else:
    print("Skipping block type statistics as 'block_id' column is missing or DataFrame is empty.")
# Out:
# Traitement des fichiers:   0%|          | 0/46 [00:00<?, ?it/s]
# <style type="text/css">
# #T_860b1 th {
#   background-color: #4CAF50;
#   color: white;
# }
# #T_860b1_row0_col0, #T_860b1_row0_col1, #T_860b1_row0_col2, #T_860b1_row0_col3, #T_860b1_row0_col4, #T_860b1_row0_col5, #T_860b1_row1_col0, #T_860b1_row1_col1, #T_860b1_row1_col2, #T_860b1_row1_col3, #T_860b1_row1_col4, #T_860b1_row1_col5, #T_860b1_row2_col0, #T_860b1_row2_col1, #T_860b1_row2_col2, #T_860b1_row2_col3, #T_860b1_row2_col4, #T_860b1_row2_col5, #T_860b1_row3_col0, #T_860b1_row3_col1, #T_860b1_row3_col2, #T_860b1_row3_col3, #T_860b1_row3_col4, #T_860b1_row3_col5, #T_860b1_row4_col0, #T_860b1_row4_col1, #T_860b1_row4_col2, #T_860b1_row4_col3, #T_860b1_row4_col4, #T_860b1_row4_col5, #T_860b1_row5_col0, #T_860b1_row5_col1, #T_860b1_row5_col2, #T_860b1_row5_col3, #T_860b1_row5_col4, #T_860b1_row5_col5, #T_860b1_row6_col0, #T_860b1_row6_col1, #T_860b1_row6_col2, #T_860b1_row6_col3, #T_860b1_row6_col4, #T_860b1_row6_col5, #T_860b1_row7_col0, #T_860b1_row7_col1, #T_860b1_row7_col2, #T_860b1_row7_col3, #T_860b1_row7_col4, #T_860b1_row7_col5, #T_860b1_row8_col0, #T_860b1_row8_col1, #T_860b1_row8_col2, #T_860b1_row8_col3, #T_860b1_row8_col4, #T_860b1_row8_col5, #T_860b1_row9_col0, #T_860b1_row9_col1, #T_860b1_row9_col2, #T_860b1_row9_col3, #T_860b1_row9_col4, #T_860b1_row9_col5, #T_860b1_row10_col0, #T_860b1_row10_col1, #T_860b1_row10_col2, #T_860b1_row10_col3, #T_860b1_row10_col4, #T_860b1_row10_col5, #T_860b1_row11_col0, #T_860b1_row11_col1, #T_860b1_row11_col2, #T_860b1_row11_col3, #T_860b1_row11_col4, #T_860b1_row11_col5, #T_860b1_row12_col0, #T_860b1_row12_col1, #T_860b1_row12_col2, #T_860b1_row12_col3, #T_860b1_row12_col4, #T_860b1_row12_col5, #T_860b1_row13_col0, #T_860b1_row13_col1, #T_860b1_row13_col2, #T_860b1_row13_col3, #T_860b1_row13_col4, #T_860b1_row13_col5, #T_860b1_row14_col0, #T_860b1_row14_col1, #T_860b1_row14_col2, #T_860b1_row14_col3, #T_860b1_row14_col4, #T_860b1_row14_col5 {
#   text-align: left;
#   border-color: white;
#   font-size: 12px;
# }
# </style>
# <table id="T_860b1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_860b1_level0_col0" class="col_heading level0 col0" >block_id</th>
#       <th id="T_860b1_level0_col1" class="col_heading level0 col1" >coords</th>
#       <th id="T_860b1_level0_col2" class="col_heading level0 col2" >text</th>
#       <th id="T_860b1_level0_col3" class="col_heading level0 col3" >article_id</th>
#       <th id="T_860b1_level0_col4" class="col_heading level0 col4" >embedding</th>
#       <th id="T_860b1_level0_col5" class="col_heading level0 col5" >source_file</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_860b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_860b1_row0_col0" class="data row0 col0" >region_1593176077803_5867</td>
#       <td id="T_860b1_row0_col1" class="data row0 col1" >(0.23885024549918166, 0.03056062947871294)</td>
#       <td id="T_860b1_row0_col2" class="data row0 col2" >courrier des théatres</td>
#       <td id="T_860b1_row0_col3" class="data row0 col3" >19220115_1-0005.xml_a2</td>
#       <td id="T_860b1_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_860b1_row0_col5" class="data row0 col5" >19220115_1-0005.xml</td>
#     </tr>
#     <tr>
#       <th id="T_860b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_860b1_row1_col0" class="data row1 col0" >region_1593176094128_5870</td>
#       <td id="T_860b1_row1_col1" class="data row1 col1" >(0.07538870703764321, 0.04868624420401855)</td>
#       <td id="T_860b1_row1_col2" class="data row1 col2" >e</td>
#       <td id="T_860b1_row1_col3" class="data row1 col3" >19220115_1-0005.xml_a2</td>
#       <td id="T_860b1_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_860b1_row1_col5" class="data row1 col5" >19220115_1-0005.xml</td>
#     </tr>
#     <tr>
#       <th id="T_860b1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_860b1_row2_col0" class="data row2 col0" >r_6_1</td>
#       <td id="T_860b1_row2_col1" class="data row2 col1" >(0.0765139116202946, 0.07418856259659969)</td>
#       <td id="T_860b1_row2_col2" class="data row2 col2" >aujourd'hui, matinée exceptionnellement atayante, avec le grand succès de la saison le aradis ferme, suivi de l' uvre impérissable de ollère les precieuses ridicules. m. bofenerg, qui obtint au conservatoire son prix de coméle dans le rôle de mascarille, interprétera ce pernnage légendaire, entouré de mmes madeleine oria, alice beylat, meg degaral et de mm. arudy, g. gallet. ch. mosnier, bonvallet, toureur capoul, lévin, etc. en raison de la londeur du spectacle, on commencera à 1 h. 45.</td>
#       <td id="T_860b1_row2_col3" class="data row2 col3" >19220115_1-0005.xml_a2</td>
#       <td id="T_860b1_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_860b1_row2_col5" class="data row2 col5" >19220115_1-0005.xml</td>
#     </tr>
#     <tr>
#       <th id="T_860b1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_860b1_row3_col0" class="data row3 col0" >region_1593176098153_5873</td>
#       <td id="T_860b1_row3_col1" class="data row3 col1" >(0.0743657937806874, 0.1028523254180132)</td>
#       <td id="T_860b1_row3_col2" class="data row3 col2" >en arrivant de cannes...</td>
#       <td id="T_860b1_row3_col3" class="data row3 col3" >19220115_1-0005.xml_a3</td>
#       <td id="T_860b1_row3_col4" class="data row3 col4" >None</td>
#       <td id="T_860b1_row3_col5" class="data row3 col5" >19220115_1-0005.xml</td>
#     </tr>
#     <tr>
#       <th id="T_860b1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_860b1_row4_col0" class="data row4 col0" >r_27_1</td>
#       <td id="T_860b1_row4_col1" class="data row4 col1" >(0.07671849427168576, 0.21701559645918225)</td>
#       <td id="T_860b1_row4_col2" class="data row4 col2" >qu'estce que vous voulez, messieurs, en atndant... allons toujours voir jouer le chasseur e chez maxim's au palaisroyal.</td>
#       <td id="T_860b1_row4_col3" class="data row4 col3" >19220115_1-0005.xml_a3</td>
#       <td id="T_860b1_row4_col4" class="data row4 col4" >None</td>
#       <td id="T_860b1_row4_col5" class="data row4 col5" >19220115_1-0005.xml</td>
#     </tr>
#     <tr>
#       <th id="T_860b1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_860b1_row5_col0" class="data row5 col0" >r_27_2</td>
#       <td id="T_860b1_row5_col1" class="data row5 col1" >(0.07467266775777415, 0.22565687789799072)</td>
#       <td id="T_860b1_row5_col2" class="data row5 col2" >aujourd'hui matinée à 2 h. 30</td>
#       <td id="T_860b1_row5_col3" class="data row5 col3" >19220115_1-0005.xml_a3</td>
#       <td id="T_860b1_row5_col4" class="data row5 col4" >None</td>
#       <td id="T_860b1_row5_col5" class="data row5 col5" >19220115_1-0005.xml</td>
#     </tr>
#     <tr>
#       <th id="T_860b1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_860b1_row6_col0" class="data row6 col0" >region_1593176246372_5889</td>
#       <td id="T_860b1_row6_col1" class="data row6 col1" >(0.23833878887070375, 0.16994520162990023)</td>
#       <td id="T_860b1_row6_col2" class="data row6 col2" >lnée. on donnera l'amoureuse sans le savoir, le nouveau chefd' uvre de m. gabriel nigond.</td>
#       <td id="T_860b1_row6_col3" class="data row6 col3" >19220115_1-0005.xml_a21</td>
#       <td id="T_860b1_row6_col4" class="data row6 col4" >None</td>
#       <td id="T_860b1_row6_col5" class="data row6 col5" >19220115_1-0005.xml</td>
#     </tr>
#     <tr>
#       <th id="T_860b1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_860b1_row7_col0" class="data row7 col0" >region_1593176252394_5892</td>
#       <td id="T_860b1_row7_col1" class="data row7 col1" >(0.2397708674304419, 0.18385555711676269)</td>
#       <td id="T_860b1_row7_col2" class="data row7 col2" >a main passe. mme raymonde machard et l m. rené cellier ont pris la direction du théatre albert1er. on y répète un million dans la main d'un enfant, de m. alfred machard.</td>
#       <td id="T_860b1_row7_col3" class="data row7 col3" >19220115_1-0005.
# Statistiques des types de blocs :
# block_id
# Auto (r_...)           15553
# Manuel (Region_...)      320
# Name: count, dtype: int64

# %%
# --- AFFICHAGE DES STATISTIQUES ---
print("\n" + "="*40)
print("📊 RÉSUMÉ DU TRAITEMENT")
print("="*40)
print(f"📁 Nombre de fichiers XML récupérés : {len(files)}")
print(f"📑 Nombre total de blocs de texte    : {len(df)}")
# On compte les IDs uniques en ignorant les "N/A"
unique_articles = df[df['article_id'] != "N/A"]['article_id'].nunique()
print(f"📰 Nombre d'articles uniques trouvés : {unique_articles}")

# Statistiques des types de blocs
id_type = df['block_id'].apply(lambda x: 'Manuel (Region_...)' if 'region' in x.lower() else 'Auto (r_...)')
print("\nStatistiques des types de blocs :")
print(id_type.value_counts())
print("="*40)

# Affichage du DataFrame
display(df.head(10))
# Out:
# ========================================
# 📊 RÉSUMÉ DU TRAITEMENT
# ========================================
# 📁 Nombre de fichiers XML récupérés : 46
# 📑 Nombre total de blocs de texte    : 15873
# 📰 Nombre d'articles uniques trouvés : 1614
#
# Statistiques des types de blocs :
# block_id
# Auto (r_...)           15553
# Manuel (Region_...)      320
# Name: count, dtype: int64
# ========================================
#                     block_id                                      coords  \
# 0  region_1593176077803_5867  (0.23885024549918166, 0.03056062947871294)
# 1  region_1593176094128_5870  (0.07538870703764321, 0.04868624420401855)
# 2                      r_6_1   (0.0765139116202946, 0.07418856259659969)
# 3  region_1593176098153_5873    (0.0743657937806874, 0.1028523254180132)
# 4                     r_27_1  (0.07671849427168576, 0.21701559645918225)
# 5                     r_27_2  (0.07467266775777415, 0.22565687789799072)
# 6  region_1593176246372_5889  (0.23833878887070375, 0.16994520162990023)
# 7  region_1593176252394_5892   (0.2397708674304419, 0.18385555711676269)
# 8  region_1593176261516_5895  (0.21307283142389524, 0.19425319657158915)
# 9  region_1593176266038_5898  (0.23956628477905073, 0.20247295208655333)
#
#                                                 text               article_id  \
# 0                              courrier des théatres   19220115_1-0005.xml_a2
# 1                                                  e   19220115_1-0005.xml_a2
# 2  aujourd'hui, matinée exceptionnellement atayan...   19220115_1-0005.xml_a2
# 3                           en arrivant de cannes...   19220115_1-0005.xml_a3
# 4  qu'estce que vous voulez, messieurs, en atndan...   19220115_1-0005.xml_a3
# 5                      aujourd'hui matinée à 2 h. 30   19220115_1-0005.xml_a3
# 6  lnée. on donnera l'amoureuse sans le savoir, l...  19220115_1-0005.xml_a21
# 7  a main passe. mme raymonde machard et l m. ren...  19220115_1-0005.xml_a21
# 8                           pectacles de la semaine.  19220115_1-0005.xml_a21
# 9  opéra. lundi, les troyens, mercredi, hérodiade...  19220115_1-0005.xml_a21
#
#   embedding          source_file
# 0      None  19220115_1-0005.xml
# 1      None  19220115_1-0005.xml
# 2      None  19220115_1-0005.xml
# 3      None  19220115_1-0005.xml
# 4      None  19220115_1-0005.xml
# 5      None  19220115_1-0005.xml
# 6      None  19220115_1-0005.xml
# 7      None  19220115_1-0005.xml
# 8      None  19220115_1-0005.xml
# 9      None  19220115_1-0005.xml

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import StandardScaler
import numpy as np

# 1. Chargement du modèle MiniLM (très efficace pour le français)
print("Chargement du modèle MiniLM...")
model_st = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

# 2. Génération des embeddings textuels
print("Génération des vecteurs de sens (Text Embeddings)...")
# On utilise la colonne 'text' qui contient ton texte nettoyé
text_embeddings = model_st.encode(df['text'].tolist(), show_progress_bar=True)
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# Chargement du modèle MiniLM...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/526 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Génération des vecteurs de sens (Text Embeddings)...
# Batches:   0%|          | 0/497 [00:00<?, ?it/s]

# %%
# 1. Préparation des coordonnées
spatial_data = np.array(df['coords'].tolist()) # Shape (N, 2)
scaler = StandardScaler()
spatial_scaled = scaler.fit_transform(spatial_data)

# 2. Projection des coordonnées vers 384 dimensions
# On crée une matrice de poids fixe pour étaler cx/cy sur 384 dimensions
np.random.seed(42)
projection_matrix = np.random.randn(2, 384)
spatial_projected = spatial_scaled @ projection_matrix

# 3. Calcul de la Somme Pondérée
alpha = 0.7  # Poids du texte
beta = 0.3   # Poids de la position (spatial)

X_sum = (alpha * text_embeddings) + (beta * spatial_projected)

# 4. Mise à jour du DataFrame
df['embedding'] = list(X_sum)

print(f"Somme pondérée terminée. Taille finale : {X_sum.shape}")
# Out:
# Somme pondérée terminée. Taille finale : (15873, 384)

# %%
# 1. Préparation des coordonnées (Déjà fait dans votre code)
spatial_data = np.array(df['coords'].tolist())
scaler = StandardScaler()
spatial_scaled = scaler.fit_transform(spatial_data)
# 2. CONCATÉNATION
# On définit un poids pour la position.
# Plus 'weight_spatial' est grand, plus l'IA regroupera les blocs par proximité physique.
weight_spatial = 5.0

# On accole les 384 dimensions du texte et les 2 dimensions de position
X_final = np.hstack((text_embeddings, spatial_scaled * weight_spatial))

# 3. Mise à jour du DataFrame
df['embedding'] = list(X_final)

print(f"✅ Concaténation terminée.")
print(f"Taille de la matrice finale : {X_final.shape}") # Résultat : (N, 386)
# Out:
# ✅ Concaténation terminée.
# Taille de la matrice finale : (15873, 386)

# %%
from sklearn.metrics.pairwise import cosine_distances

# Convertir X_sum en float32 avant le calcul
matrix = cosine_distances(X_sum.astype('float32')).astype('float32')

# %%
clustering = AgglomerativeClustering(
    n_clusters=None,
    distance_threshold=0.135,
    metric='cosine', # Calcule le cosinus bloc par bloc
    linkage='average'
)

# On passe X_sum directement
df['cluster_label'] = clustering.fit_predict(X_sum)

# %%
from sklearn.cluster import AgglomerativeClustering

# On utilise directement X_sum au lieu de la matrice de distance
# On change metric='precomputed' par metric='cosine'
clustering = AgglomerativeClustering(
    n_clusters=None,
    distance_threshold=5.8,
    metric='euclidean', # Calcule le cosinus bloc par bloc
    linkage='ward'
)

# On passe X_sum directement
df['cluster_label'] = clustering.fit_predict(X_final)

# %%
# 4. Évaluation (uniquement sur les blocs ayant une vérité terrain)
df_eval = df[df['article_id'] != "N/A"].copy()

if not df_eval.empty:
    true_labels = LabelEncoder().fit_transform(df_eval['article_id'])
    score = v_measure_score(true_labels, df_eval.loc[df_eval.index, 'cluster_label'])

    print("\n" + "="*30)
    print(f"RÉSULTATS DU CLUSTERING")
    print("="*30)
    print(f"Précision (V-Measure) : {score:.4f}")
    print(f"Nombre d'articles (clusters) : {df['cluster_label'].nunique()}")
    print(f"Vrais articles en base : {df_eval['article_id'].nunique()}")
    print("="*30)
else:
    print("Erreur : Aucune donnée avec article_id valide pour l'évaluation.")
# Out:
# ==============================
# RÉSULTATS DU CLUSTERING
# ==============================
# Précision (V-Measure) : 0.7140
# Nombre d'articles (clusters) : 2033
# Vrais articles en base : 1614
# ==============================

# %%
from sklearn.metrics import adjusted_rand_score

# Calcul du score ARI
# true_labels : les IDs uniques (Fichier + Article)
# cluster_label : les prédictions de ton IA
ari_score = adjusted_rand_score(true_labels, df_eval['cluster_label'])

print(f"Score ARI : {ari_score:.4f}")
# Out:
# Score ARI : 0.0530

# %% [markdown]
# # RÉSULTATS DU CLUSTERING
# 0.7 sens 0.3 coords
# ==============================
# Précision (V-Measure) : 0.1497
#
# Nombre d'articles (clusters) : 257
#
# Vrais articles en base : 77
#
# ==============================
#
# 0.5 sens 0.5 coords
#
# Précision (V-Measure) : 0.1111
#
# Nombre d'articles (clusters) : 57
#
# Vrais articles en base : 77

# %%
from sklearn.metrics import v_measure_score
from sklearn.preprocessing import LabelEncoder

df_eval = df[df['article_id'] != "N/A"].copy()
if not df_eval.empty:
    true_labels = LabelEncoder().fit_transform(df_eval['article_id'])
    score = v_measure_score(true_labels, df_eval['cluster_label'])
    print(f"Précision du modèle (V-Measure) : {score:.4f}")
    print(f"Nombre d'articles reconstitués : {df['cluster_label'].nunique()}")
# Out:
# Précision du modèle (V-Measure) : 0.1006
# Nombre d'articles reconstitués : 4

# %% [markdown]
# 1. La logique du "Lien" plutôt que du "Nom"
#
# Le score (V-Measure) ne regarde jamais si le chiffre est identique. Il se pose une seule question : "Est-ce que les morceaux qui étaient ensemble dans la réalité sont restés ensemble dans ton résultat ?".
#
#     Dans ton exemple : L'article 11 possède 3 morceaux. Ton IA les a mis tous les trois dans le groupe 1383. Pour le calcul du score, c'est une réussite totale (100%), car l'IA a compris que ces trois morceaux forment un bloc unique, peu importe qu'elle l'appelle "1383" ou "banane".
#
#     Le score monte quand les "liens" sont respectés.
#
#     Le score baisse uniquement si l'IA sépare des morceaux qui devraient être ensemble, ou si elle mélange des morceaux d'articles différents.
#
# 2. Comment l'IA "reconnaît" les morceaux sans connaître les articles ?
#
# Ton modèle utilise deux types de "lunettes" pour regrouper les textes :
#
#     Les lunettes sémantiques (MiniLM) : Il "lit" le sens. Si un bloc parle d'un "ivrogne dans un salon" et le suivant aussi, l'IA calcule que la distance sémantique est presque nulle.
#
#     Les lunettes spatiales (cx, cy) : Ton code donne un poids (weight_spatial = 2.0) à la position. Si deux blocs sont collés sur la page, l'IA considère qu'ils ont de grandes chances d'appartenir au même article.
#
# 3. Pourquoi 0,75 et pas 1,00 ?
#
# Le 0,75 signifie que dans 75% des cas, l'IA a pris les bonnes décisions de groupement. Les 25% manquants (les erreurs) viennent généralement de deux phénomènes que l'on voit sur ta matrice :
#
#     La fragmentation (Complétude < 1) : L'IA a trouvé que le début de l'article est un groupe, mais elle a cru que la fin était un autre article (souvent à cause d'un saut de page ou d'un changement de ton).
#
#     La fusion (Homogénéité < 1) : Deux petits articles qui parlent du même sujet et qui sont proches physiquement (ex: deux brèves de faits divers) ont été fusionnés dans un seul gros cluster par l'IA.
#
# En résumé : Ton IA est comme une personne qui doit trier des chaussettes sans savoir à qui elles appartiennent. Elle réussit à 75% parce qu'elle regroupe bien les chaussettes par couleur et par taille, même si elle ne sait pas qu'elles appartiennent à "Monsieur 14" ou "Madame 22".

# %%
import os
from lxml import etree
import pandas as pd
from datetime import datetime

def generer_xml_reconstruits_limite(df, dossier_sortie="/content/drive/MyDrive/chef-douvre/output_predict", nb_max=5):
    """
    Génère des fichiers PAGE XML à partir des clusters prédits.
    Limite la sortie aux nb_max premiers fichiers source rencontrés.
    """
    # Création du dossier s'il n'existe pas
    if not os.path.exists(dossier_sortie):
        os.makedirs(dossier_sortie)

    # 1. Sélectionner uniquement les 5 premiers fichiers uniques du DataFrame
    fichiers_uniques = df['source_file'].unique()[:nb_max]
    df_selection = df[df['source_file'].isin(fichiers_uniques)]

    print(f"🚀 Préparation de la génération pour {len(fichiers_uniques)} fichiers...")

    # 2. On groupe par fichier pour la génération
    for nom_fichier, group in df_selection.groupby('source_file'):

        # Configuration des Namespaces PAGE XML
        NS = "http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15"
        nsmap = {None: NS}

        root = etree.Element("PcGts", nsmap=nsmap)

        # Métadonnées
        metadata = etree.SubElement(root, "Metadata")
        etree.SubElement(metadata, "Creator").text = "Gemini_Clustering_Pipeline_v2"
        etree.SubElement(metadata, "Created").text = datetime.now().isoformat()

        # Structure de la Page
        page = etree.SubElement(root, "Page", imageFilename=nom_fichier)

        # 3. Parcours des blocs du fichier
        for _, row in group.iterrows():
            # On conserve le block_id d'origine pour la cohérence
            region_id = str(row['block_id'])

            # On utilise le cluster prédit comme ID d'article (ex: c0, c1...)
            cluster_id = f"c{row['cluster_label']}"

            # Formatage de l'attribut custom conforme au format source
            custom_attr = f"readingOrder {{index:0;}} structure {{id:{cluster_id}; type:article;}}"

            text_region = etree.SubElement(page, "TextRegion", id=region_id, custom=custom_attr)

            # Coordonnées (cx, cy)
            cx, cy = row['coords']
            etree.SubElement(text_region, "Coords", points=f"{cx},{cy}")

            # Texte Unicode
            text_equiv = etree.SubElement(text_region, "TextEquiv")
            unicode_node = etree.SubElement(text_equiv, "Unicode")
            unicode_node.text = str(row['text'])

        # 4. Écriture du fichier sur le Drive
        nom_sortie = f"predict_{nom_fichier}"
        if not nom_sortie.endswith('.xml'):
            nom_sortie += ".xml"

        chemin_sortie = os.path.join(dossier_sortie, nom_sortie)

        with open(chemin_sortie, "wb") as f:
            f.write(etree.tostring(root, pretty_print=True, xml_declaration=True, encoding="UTF-8"))

        print(f"✅ Fichier généré : {nom_sortie}")

    print(f"\n--- Fin du traitement ---")
    print(f"📁 Dossier de sortie : {dossier_sortie}")

# --- LANCEMENT ---
generer_xml_reconstruits_limite(df, nb_max=5)
# Out:
# 🚀 Préparation de la génération pour 5 fichiers...
# ✅ Fichier généré : predict_18720715_1-0004.xml
# ✅ Fichier généré : predict_18970715_1-0001.xml
# ✅ Fichier généré : predict_19220115_1-0003.xml
# ✅ Fichier généré : predict_19220115_1-0005.xml
# ✅ Fichier généré : predict_19300115_1-0004.xml
#
# --- Fin du traitement ---
# 📁 Dossier de sortie : /content/drive/MyDrive/chef-douvre/output_predict

# %% [markdown]
# J'ai utilisé un modèle de langage multilingue couplé à une analyse de la mise en page (coordonnées spatiales). Mon algorithme a regroupé les 4000 segments d'OCR en 1631 articles avec une précision de 75% par rapport à la vérité terrain. Cela permet de reconstruire automatiquement la structure logique du journal là où elle était perdue.
#
#
# 3. La Validation : Pourquoi le score est fiable
#
# C'est ici que tu justifies ton résultat technique :
#
#
# Indépendance des labels : Précise bien que l'IA a "aveuglément" créé 1631 clusters sans connaître les vrais articles.
#
# V-Measure : Explique que ce score mesure la corrélation structurelle. Un score de 0,75 prouve que dans 75% des cas, les frontières d'articles décidées par l'IA correspondent exactement aux frontières tracées par les experts dans le XML.
